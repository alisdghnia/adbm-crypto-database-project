# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/Users/alisdghnia/Desktop/School - Graduate/Advanced Database Management - Spring 2023/Final Project')

# %%
df = pd.read_csv('exchange wallets.csv')
df
# Out:
#     ticker_name                                         ticker_url  \
# 0         1 BTC       https://www.coincarp.com/currencies/bitcoin/
# 1         1 BTC       https://www.coincarp.com/currencies/bitcoin/
# 2         1 BTC       https://www.coincarp.com/currencies/bitcoin/
# 3         1 BTC       https://www.coincarp.com/currencies/bitcoin/
# 4         1 BTC       https://www.coincarp.com/currencies/bitcoin/
# ..          ...                                                ...
# 338     20 WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 339     20 WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 340     20 WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 341     20 WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 342     20 WBTC  https://www.coincarp.com/currencies/wrapped-bi...
#
#     ticker_exchange_name ticker_exchange_tokenbalance ticker_exchange_value  \
# 0                Binance                  421,388 BTC      $12,835,455,120
# ...

# %%
df = df.fillna(0)

# %%
# remove the number strings in the ticker name column
df['ticker_name'] = df['ticker_name'].str.replace(r'\d+', '')

# remove the spaces in the ticker name column
df['ticker_name'] = df['ticker_name'].str.replace(' ', '')
# Out:
# /var/folders/_9/qq7pw_fx125c812gfv1wl_180000gn/T/ipykernel_38651/1126906103.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['ticker_name'] = df['ticker_name'].str.replace(r'\d+', '')

# %%
df
# Out:
#     ticker_name                                         ticker_url  \
# 0           BTC       https://www.coincarp.com/currencies/bitcoin/
# 1           BTC       https://www.coincarp.com/currencies/bitcoin/
# 2           BTC       https://www.coincarp.com/currencies/bitcoin/
# 3           BTC       https://www.coincarp.com/currencies/bitcoin/
# 4           BTC       https://www.coincarp.com/currencies/bitcoin/
# ..          ...                                                ...
# 338        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 339        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 340        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 341        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 342        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
#
#     ticker_exchange_name ticker_exchange_tokenbalance ticker_exchange_value  \
# 0                Binance                  421,388 BTC      $12,835,455,120
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ticker_name                     343 non-null    object
#  1   ticker_url                      343 non-null    object
#  2   ticker_exchange_name            343 non-null    object
#  3   ticker_exchange_tokenbalance    343 non-null    object
#  4   ticker_exchange_value           343 non-null    object
#  5   ticker_exchange_selection1      343 non-null    object
#  6   ticker_exchange_sevendaychange  343 non-null    object
#  7   ticker_exchange_threedaychange  343 non-null    object
# dtypes: object(8)
# memory usage: 21.6+ KB

# %%
lst_col = ['ticker_exchange_tokenbalance', 'ticker_exchange_selection1', 'ticker_exchange_sevendaychange', 'ticker_exchange_threedaychange']

for col in lst_col:
    try:
        # get rid of the letters in the columns
        df[col] = df[col].str.replace(r'[a-zA-Z]+', '')

        # get rid of the spaces in the columns
        df[col] = df[col].str.replace(' ', '')

        # get rid of the commas in the columns
        df[col] = df[col].str.replace(',', '')

        # turn the columns into floats
        df[col] = df[col].astype(float)

        # change NaN values to 0
        df[col] = df[col].fillna(0)
    except Exception as e:
        # print the row that caused the error
        pass
# Out:
# /var/folders/_9/qq7pw_fx125c812gfv1wl_180000gn/T/ipykernel_38651/1107891482.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[col] = df[col].str.replace(r'[a-zA-Z]+', '')

# %%
# replace the empty strings with 0
df['ticker_exchange_threedaychange'] = df['ticker_exchange_threedaychange'].replace('', 0)
# replace -- with 0
df['ticker_exchange_threedaychange'] = df['ticker_exchange_threedaychange'].replace('--', 0)
df['ticker_exchange_threedaychange'] = df['ticker_exchange_threedaychange'].astype(float)


# Same with sevendaychange column
df['ticker_exchange_sevendaychange'] = df['ticker_exchange_sevendaychange'].replace('', 0)
df['ticker_exchange_sevendaychange'] = df['ticker_exchange_sevendaychange'].replace('--', 0)
df['ticker_exchange_sevendaychange'] = df['ticker_exchange_sevendaychange'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ticker_name                     343 non-null    object
#  1   ticker_url                      343 non-null    object
#  2   ticker_exchange_name            343 non-null    object
#  3   ticker_exchange_tokenbalance    343 non-null    float64
#  4   ticker_exchange_value           343 non-null    object
#  5   ticker_exchange_selection1      343 non-null    float64
#  6   ticker_exchange_sevendaychange  342 non-null    float64
#  7   ticker_exchange_threedaychange  342 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 21.6+ KB

# %%
df.ticker_name.unique()
# Out:
# array(['BTC', 'ETH', 'USDT', 'BNB', 'USDC', 'XRP', 'ADA', 'DOGE', 'OKB',
#        'MATIC', 'SOL', 'DOT', 'LTC', 'BUSD', 'SHIB', 'DAI', 'AVAX', 'TRX',
#        'UNI', 'WBTC'], dtype=object)

# %%
df.columns = ['ticker_name', 'ticker_url', 'exchange_name', 'exchange_token_balance (cryptocurrency)', 'exchange_value', 'selection1 (cryptocurrency)',
                    'seven_day_change (cryptocurrency)', 'three_day_change (cryptocurrency)']
    
    # reset the index
df.reset_index(drop=True, inplace=True)
df
# Out:
#     ticker_name                                         ticker_url  \
# 0           BTC       https://www.coincarp.com/currencies/bitcoin/
# 1           BTC       https://www.coincarp.com/currencies/bitcoin/
# 2           BTC       https://www.coincarp.com/currencies/bitcoin/
# 3           BTC       https://www.coincarp.com/currencies/bitcoin/
# 4           BTC       https://www.coincarp.com/currencies/bitcoin/
# ..          ...                                                ...
# 338        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 339        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 340        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 341        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
# 342        WBTC  https://www.coincarp.com/currencies/wrapped-bi...
#
#            exchange_name  exchange_token_balance (cryptocurrency)  \
# 0                Binance                              421388.0000
# ...

# %%
df.to_csv('exchange wallets all.csv', index=False)

# %%
# create a dataframe for each of the ticker_names
btc = df[df['ticker_name'] == 'BTC']
eth = df[df['ticker_name'] == 'ETH']
xrp = df[df['ticker_name'] == 'XRP']
ltc = df[df['ticker_name'] == 'LTC']

bnb = df[df['ticker_name'] == 'BNB']
usdt = df[df['ticker_name'] == 'USDT']
trx = df[df['ticker_name'] == 'TRX']
uni = df[df['ticker_name'] == 'UNI']

usdc = df[df['ticker_name'] == 'USDC']
ada = df[df['ticker_name'] == 'ADA']
doge = df[df['ticker_name'] == 'DOGE']
okb = df[df['ticker_name'] == 'OKB']

matic = df[df['ticker_name'] == 'MATIC']
sol = df[df['ticker_name'] == 'SOL']
dot = df[df['ticker_name'] == 'DOT']
busd = df[df['ticker_name'] == 'BUSD']

shib = df[df['ticker_name'] == 'SHIB']
dai = df[df['ticker_name'] == 'DAI']
avax = df[df['ticker_name'] == 'AVAX']
wbtc = df[df['ticker_name'] == 'WBTC']

# %%
df_lst = [btc, eth, xrp, ltc, bnb, usdt, trx, uni, usdc, ada, doge, okb, matic, sol, dot, busd, shib, dai, avax, wbtc]

# %%
for i in df_lst:
    # print( i.ticker_name.unique() )
    # rename the columns to be more descriptive
    i.columns = ['ticker_name', 'ticker_url', 'exchange_name', f'exchange_token_balance {i.ticker_name.unique()}', 'exchange_value', f'selection1 {i.ticker_name.unique()}',
                    f'seven_day_change {i.ticker_name.unique()}', f'three_day_change {i.ticker_name.unique()}']
    
    # reset the index
    i.reset_index(drop=True, inplace=True)

# %%
# save all the dataframes to csv files
btc.to_csv('btc.csv')
eth.to_csv('eth.csv')
xrp.to_csv('xrp.csv')
ltc.to_csv('ltc.csv')

bnb.to_csv('bnb.csv')
usdt.to_csv('usdt.csv')
trx.to_csv('trx.csv')
uni.to_csv('uni.csv')

usdc.to_csv('usdc.csv')
ada.to_csv('ada.csv')
doge.to_csv('doge.csv')
okb.to_csv('okb.csv')

matic.to_csv('matic.csv')
sol.to_csv('sol.csv')
dot.to_csv('dot.csv')
busd.to_csv('busd.csv')

shib.to_csv('shib.csv')
dai.to_csv('dai.csv')
avax.to_csv('avax.csv')
wbtc.to_csv('wbtc.csv')
